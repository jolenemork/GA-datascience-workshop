# %%
import pandas as pd

# %% [markdown]
# #<h1>Manipulating DataFrames</h1>

# %% [markdown]
# Load the data into a DataFrame:

# %%
data = pd.read_csv('sales-funnel.csv')
data
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 12   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 13   307599   Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 14   688981                   Keeling LLC     Wendy Yule  Fred Anderson
# 15   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
# 16   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 0           CPU         1   30000  presented
# 1      Software         1   10000  presented
# 2   Maintenance         2    5000    pending
# 3           CPU         1   35000   declined
# 4           CPU         2   65000        won
# 5           CPU         2   40000    pending
# 6      Software         1   10000  presented
# 7   Maintenance         2    5000    pending
# 8           CPU         1   35000   declined
# 9           CPU         2   65000        won
# 10          CPU         1   30000  presented
# 11  Maintenance         1    5000    pending
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won
# 15          CPU         2   65000   declined
# 16      Monitor         2    5000  presented

# %% [markdown]
# View the column names:

# %%
data.columns
# Out:
# Index([u'Account', u'Name', u'Rep', u'Manager', u'Product', u'Quantity',
#        u'Price', u'Status'],
#       dtype='object')

# %% [markdown]
# View the first/last N rows:

# %%
data.head(3)
data.tail()
# Out:
#     Account                         Name          Rep        Manager  \
# 12   239344                   Stokes LLC  Cedric Moss  Fred Anderson
# 13   307599  Kassulke, Ondricka and Metz   Wendy Yule  Fred Anderson
# 14   688981                  Keeling LLC   Wendy Yule  Fred Anderson
# 15   729833                    Koepp Ltd   Wendy Yule  Fred Anderson
# 16   729833                    Koepp Ltd   Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won
# 15          CPU         2   65000   declined
# 16      Monitor         2    5000  presented

# %% [markdown]
# View a few select rows:

# %%
data[10:13]
# Out:
#     Account         Name          Rep        Manager      Product  Quantity  \
# 10   163416  Purdy-Kunde  Cedric Moss  Fred Anderson          CPU         1
# 11   239344   Stokes LLC  Cedric Moss  Fred Anderson  Maintenance         1
# 12   239344   Stokes LLC  Cedric Moss  Fred Anderson     Software         1
#
#     Price     Status
# 10  30000  presented
# 11   5000    pending
# 12  10000  presented

# %% [markdown]
# View a few select columns:

# %%
data[['Manager','Price','Status']]
# Out:
#           Manager   Price     Status
# 0    Debra Henley   30000  presented
# 1    Debra Henley   10000  presented
# 2    Debra Henley    5000    pending
# 3    Debra Henley   35000   declined
# 4    Debra Henley   65000        won
# 5    Debra Henley   40000    pending
# 6    Debra Henley   10000  presented
# 7    Debra Henley    5000    pending
# 8    Debra Henley   35000   declined
# 9   Fred Anderson   65000        won
# 10  Fred Anderson   30000  presented
# 11  Fred Anderson    5000    pending
# 12  Fred Anderson   10000  presented
# 13  Fred Anderson    7000        won
# 14  Fred Anderson  100000        won
# 15  Fred Anderson   65000   declined
# 16  Fred Anderson    5000  presented

# %%
data.Manager
# Out:
# 0      Debra Henley
# 1      Debra Henley
# 2      Debra Henley
# 3      Debra Henley
# 4      Debra Henley
# 5      Debra Henley
# 6      Debra Henley
# 7      Debra Henley
# 8      Debra Henley
# 9     Fred Anderson
# 10    Fred Anderson
# 11    Fred Anderson
# 12    Fred Anderson
# 13    Fred Anderson
# 14    Fred Anderson
# 15    Fred Anderson
# 16    Fred Anderson
# Name: Manager, dtype: object

# %% [markdown]
# Pull a column out and view as a Series:

# %%
type(data['Manager'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #Selecting data

# %% [markdown]
# View only rows that have Product = CPU:

# %%
# This is a "where clause", so we are looking for places where data.Product == 'CPU' returns True
data[data.Product == 'CPU']
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 14   688981                   Keeling LLC     Wendy Yule  Fred Anderson
# 15   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
#
#    Product  Quantity   Price     Status
# 0      CPU         1   30000  presented
# 3      CPU         1   35000   declined
# 4      CPU         2   65000        won
# 5      CPU         2   40000    pending
# 8      CPU         1   35000   declined
# 9      CPU         2   65000        won
# 10     CPU         1   30000  presented
# 14     CPU         5  100000        won
# 15     CPU         2   65000   declined

# %% [markdown]
# View accounts with a price less than $12,000:

# %%
data[data.Price < 12000]
# Out:
#     Account                         Name            Rep        Manager  \
# 1    714466              Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466              Trantow-Barrows   Craig Booker   Debra Henley
# 6    218895                    Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                Jerde-Hilpert     John Smith   Debra Henley
# 11   239344                   Stokes LLC    Cedric Moss  Fred Anderson
# 12   239344                   Stokes LLC    Cedric Moss  Fred Anderson
# 13   307599  Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 16   729833                    Koepp Ltd     Wendy Yule  Fred Anderson
#
#         Product  Quantity  Price     Status
# 1      Software         1  10000  presented
# 2   Maintenance         2   5000    pending
# 6      Software         1  10000  presented
# 7   Maintenance         2   5000    pending
# 11  Maintenance         1   5000    pending
# 12     Software         1  10000  presented
# 13  Maintenance         3   7000        won
# 16      Monitor         2   5000  presented

# %% [markdown]
# View the maximum account price:

# %%
data[data.Price == data.Price.max()]
# Out:
#     Account         Name         Rep        Manager Product  Quantity   Price  \
# 14   688981  Keeling LLC  Wendy Yule  Fred Anderson     CPU         5  100000
#
#    Status
# 14    won

# %% [markdown]
# Exercise: What is the minimum account price: The mean? The sum? The standard deviation?

# %%
print data.Price.describe()
# Out:
# count        17.000000
# mean      30705.882353
# std       28444.605609
# min        5000.000000
# 25%        7000.000000
# 50%       30000.000000
# 75%       40000.000000
# max      100000.000000
# Name: Price, dtype: float64

# %% [markdown]
# What is the total dollar amount pending?

# %%
data[data.Status == 'pending'].Price.sum()
# Out:
# 55000

# %% [markdown]
# How do we add columns?

# %%
data['extra'] = 'x'
data
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 12   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 13   307599   Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 14   688981                   Keeling LLC     Wendy Yule  Fred Anderson
# 15   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
# 16   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status extra
# 0           CPU         1   30000  presented     x
# 1      Software         1   10000  presented     x
# 2   Maintenance         2    5000    pending     x
# 3           CPU         1   35000   declined     x
# 4           CPU         2   65000        won     x
# 5           CPU         2   40000    pending     x
# 6      Software         1   10000  presented     x
# 7   Maintenance         2    5000    pending     x
# 8           CPU         1   35000   declined     x
# 9           CPU         2   65000        won     x
# 10          CPU         1   30000  presented     x
# 11  Maintenance         1    5000    pending     x
# 12     Software         1   10000  presented     x
# 13  Maintenance         3    7000        won     x
# 14          CPU         5  100000        won     x
# 15          CPU         2   65000   declined     x
# 16      Monitor         2    5000  presented     x

# %% [markdown]
# Let's add a column called Amount that is equal to Quantity * Price

# %%
data['Amount'] = data.Quantity*data.Price
data[data.Amount == data.Amount.max()]
# Out:
#     Account         Name         Rep        Manager Product  Quantity   Price  \
# 14   688981  Keeling LLC  Wendy Yule  Fred Anderson     CPU         5  100000
#
#    Status  Amount
# 14    won  500000

# %% [markdown]
# Exercise: Let's select just those rows where status is pending and sum up those amounts.

# %%
data[data.Status == 'pending'].Amount.sum()
# Out:
# 105000
